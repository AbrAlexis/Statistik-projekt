# %%
from sympy import *
init_printing()

# %%
x = symbols('x')

f = (x**2)*0.001444157 + (1 - x)**2 * 0.001659257 + (2*x - 2*x**2)*0.00117961

from dtumathtools import *



theDiff = f.diff(x)

dtuplot.plot(f, (x, 0, 1), xlabel="alpha", ylabel="v(alpha)")

# %%
display(solve(theDiff))

f.subs({x:0.644518767955667})
# Out:
# [0.644518767955667]
# 0.00135011550650637
